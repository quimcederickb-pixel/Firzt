# %% [markdown]
# <a href="https://colab.research.google.com/github/quimcederickb-pixel/Firzt/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while True:
  print("I hate Nel!!")
# Out:
# Streaming output truncated to the last 5000 lines.
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# I hate Nel!!
# ...
